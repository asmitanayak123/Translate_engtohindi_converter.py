# %%
from englisttohindi.englisttohindi import EngtoHindi #message to be translated
message = "my name is Asmita nayak"

#creating a EngtoHindi() object
asm = EngtoHindi(message)

#display the translation
print(asm.convert)
# Out:
# मेरा नाम अस्मिता नायक है
